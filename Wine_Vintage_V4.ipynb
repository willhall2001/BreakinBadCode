# %%
import os
import json
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pylab as plt
import requests
from bs4 import BeautifulSoup
import sqlite3
import re
from selenium import webdriver
from selenium.webdriver.common.by import By

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %%
conn = sqlite3.connect('red_wines_final 1.db')
c = conn.cursor()
wine_df = pd.read_sql_query("SELECT * FROM red_wines", conn)
wine_df = wine_df.sort_values(by='Price', ascending = False)
wine_df_filtered=wine_df.drop_duplicates(subset=['Producer', 'WineType'], keep = 'first')
wine_df_filtered=wine_df_filtered.sort_values(by='Price', ascending = False)
wine_df_filtered
# Out:
#           id                      Producer  \
# 1585    1634                    Bacigalupi
# 313      318   Domaine de La Romanée-Conti
# 366      371                        Le Pin
# 126      130                Château Pétrus
# 1676    1735        Domaine Arnoux-Lachaux
# ...      ...                           ...
# 22214  23928  Woodbridge by Robert Mondavi
# 21809  23519                       Delheim
# 22259  23975                Santa Carolina
# 22213  23927                   Félix Solís
# 22166  23879                    Crane Lake
#
#                                    WineType    Year  \
# 1585                              Zinfandel  2015.0
# 313                 Romanée-Conti Grand Cru  2010.0
# 366                                 Pomerol  1995.0
# 126                                 Pomerol  2020.0
# 1676   Vosne-Romanée 1er Cru 'Aux Reignots'  2019.0
# ...                                     ...     ...
# 22214                            Pinot Noir  2017.0
# 21809           Cabernet Sauvignon - Shiraz  2021.0
# 22259         Cabernet Sauvignon (Varietal)  2023.0
# 22213        Los Molinos Valdepeñas Crianza  2023.0
# 22166                            Pinot Noir  2016.0
#
#                                      Region        Country  \
# 1585                   Russian River Valley  United States
# 313                 Romanée-Conti Grand Cru         France
# 366                                 Pomerol         France
# 126                                 Pomerol         France
# 1676   Vosne-Romanée 1er Cru 'Aux Raignots'         France
# ...                                     ...            ...
# 22214                            California  United States
# 21809                          Stellenbosch   South Africa
# 22259                          Rapel Valley          Chile
# 22213                            Valdepeñas          Spain
# 22166                            California  United States
#
#                                                      URL  Rating  Num_Ratings  \
# 1585   https://www.vivino.com/bacigalupi-zinfandel/w/...     4.4           27
# 313    https://www.vivino.com/domaine-de-la-romanee-c...     4.7          290
# 366    https://www.vivino.com/le-pin-pomerol/w/119749...     4.7          119
# 126    https://www.vivino.com/chateau-petrus-pomerol/...     4.8           58
# 1676   https://www.vivino.com/domaine-arnoux-lachaux-...     4.3          137
# ...                                                  ...     ...          ...
# 22214  https://www.vivino.com/woodbridge-by-robert-mo...     3.3          772
# 21809  https://www.vivino.com/delheim-cabernet-sauvig...     3.7           57
# 22259  https://www.vivino.com/santa-carolina-cabernet...     3.1         3534
# 22213  https://www.vivino.com/felix-solis-los-molinos...     3.3         1249
# 22166  https://www.vivino.com/crane-lake-pinot-noir/w...     3.4          476
#
#           Price  url_idx
# 1585   54513.90       62
# 313    32000.00       12
# 366    15869.00       14
# 126    14366.00        4
# 1676    9595.00       66
# ...         ...      ...
# 22214      9.72      922
# 21809      9.05      907
# 22259      8.75      924
# 22213      8.70      922
# 22166      8.39      921
#
# [11240 rows x 11 columns]

# %%
import requests
import re
import json
import pandas as pd

# Assuming wine_df_filtered is your DataFrame that contains the URLs
wine_df_extracted = wine_df_filtered[['URL']]  

# Clean the URLs by removing query parameters (if any)
wine_df_extracted['URL'] = wine_df_extracted['URL'].str.split('?').str[0]

# Initialize lists to store the extracted data and failed URLs
all_recommended_vintages = []
all_vintages_data = []
failed_urls = []  # List to store failed URLs

# Loop through each URL in the filtered DataFrame
for index, row in wine_df_extracted.iterrows():
    url = row['URL']  # Access the URL directly
    print(f"Processing URL: {url}")  # Log the current URL being processed
    
    try:
        r = requests.get(url, headers={
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
        })

        # Check if the request was successful
        if r.status_code == 200:
            # Search for the JavaScript data in the page source
            res = re.search(r"window\.__PRELOADED_STATE__\.winePageInformation\s*=\s*(.*});", r.text, re.MULTILINE)
            
            if res:
                data = json.loads(res.group(1))

                # Extract wine details (Producer, WineType, Region, Country, Price)
                producer = data.get("wine", {}).get("producer", "")
                wine_type = data.get("wine", {}).get("type", "")
                region = data.get("wine", {}).get("region", "")
                country = data.get("wine", {}).get("country", "")
                price = data.get("wine", {}).get("price", "")  # Extract Price, if available
                
                # Extract recommended vintages
                recommended_vintages = data.get("recommended_vintages", [])
                if recommended_vintages:
                    recommended_df = pd.DataFrame(recommended_vintages)
                    recommended_df['source_url'] = url  # Add the URL for reference
                    recommended_df['Producer'] = producer
                    recommended_df['WineType'] = wine_type
                    recommended_df['Region'] = region
                    recommended_df['Country'] = country
                    recommended_df['Price'] = price  # Add the Price
                    all_recommended_vintages.append(recommended_df)

                # Extract all vintages
                all_vintages = data.get("wine", {}).get("vintages", [])
                if all_vintages:
                    all_vintages_df = pd.DataFrame(all_vintages)
                    all_vintages_df['source_url'] = url  # Add the URL for reference
                    all_vintages_df['Producer'] = producer
                    all_vintages_df['WineType'] = wine_type
                    all_vintages_df['Region'] = region
                    all_vintages_df['Country'] = country
                    all_vintages_df['Price'] = price  # Add the Price
                    all_vintages_data.append(all_vintages_df)

            else:
                print(f"No data found for URL: {url}")
                failed_urls.append(url)  # Append failed URL
        else:
            print(f"Failed to retrieve data for URL: {url}, Status code: {r.status_code}")
            failed_urls.append(url)  # Append failed URL
    
    except Exception as e:
        print(f"An error occurred for URL: {url} - {str(e)}")
        failed_urls.append(url)  # Append failed URL

# Concatenate all the recommended vintages and all vintages data into DataFrames
if all_recommended_vintages:
    final_recommended_vintages_df = pd.concat(all_recommended_vintages, ignore_index=True)
else:
    final_recommended_vintages_df = pd.DataFrame()  # Empty DataFrame if no data

if all_vintages_data:
    final_all_vintages_df = pd.concat(all_vintages_data, ignore_index=True)
else:
    final_all_vintages_df = pd.DataFrame()  # Empty DataFrame if no data

# Display the final extracted data
print("Extracted Recommended Vintages Data:")
print(final_recommended_vintages_df)

print("\nExtracted All Vintages Data:")
print(final_all_vintages_df)

# Display the failed URLs
if failed_urls:
    print("\nFailed URLs:")
    print(failed_urls)
else:
    print("\nNo failed URLs.")
# Out:
# Processing URL: https://www.vivino.com/bacigalupi-zinfandel/w/2259925
# Failed to retrieve data for URL: https://www.vivino.com/bacigalupi-zinfandel/w/2259925, Status code: 429
# Processing URL: https://www.vivino.com/domaine-de
# Failed to retrieve data for URL: https://www.vivino.com/quintarelli-giuseppe-amarone-della-valpolicella-classico-riserva/w/1187886, Status code: 429
# Processing URL: https://www.vivino.com/domaine-jean-louis-chave-l-hermitage/w/1098851
# Failed to retrieve data for URL: https://www.vivino.com/domaine-jean-louis-chave-l-hermitage/w/1098851, Status code: 429
# Processing URL: https://www.vivino.com/chateau-angelus-saint-emilion-grand-cru-premier-grand-cru-classe/w/10175
# Failed to retrieve data for URL: https://www.vivino.com/chateau-angelus-saint-emilion-grand-cru-premier-grand-cru-classe/w/10175, Status code: 429
# Processing URL: https://www.vivino.com/bond-pluribus/w/1472167

# %%
final_all_vintages_df
# Out:
#                id                    Producer                    WineType  \
# 0       176916427   bacigalupi-zinfandel-2022   Bacigalupi Zinfandel 2022
# 1       173856042   bacigalupi-zinfandel-2021   Bacigalupi Zinfandel 2021
# 2       171559100   bacigalupi-zinfandel-2020   Bacigalupi Zinfandel 2020
# 3       167792546   bacigalupi-zinfandel-2019   Bacigalupi Zinfandel 2019
# 4       164394048   bacigalupi-zinfandel-2018   Bacigalupi Zinfandel 2018
# ...           ...                         ...                         ...
# 418650   68836723  crane-lake-pinot-noir-1993  Crane Lake Pinot Noir 1993
# 418651  163293956  crane-lake-pinot-noir-1991  Crane Lake Pinot Noir 1991
# 418652   38590533  crane-lake-pinot-noir-1978  Crane Lake Pinot Noir 1978
# 418653   24872659  crane-lake-pinot-noir-1976  Crane Lake Pinot Noir 1976
# 418654    2425050    crane-lake-pinot-noir-uv       Crane Lake Pinot Noir
#
#                                                statistics  Year grapes  \
# 0       {'status': 'BelowThreshold', 'ratings_count': ...  2022   None
# 1       {'status': 'BelowThreshold', 'ratings_count': ...  2021   None
# 2       {'status': 'BelowThreshold', 'ratings_count': ...  2020   None
# 3       {'status': 'BelowThreshold', 'ratings_count': ...  2019   None
# 4       {'status': 'BelowThreshold', 'ratings_count': ...  2018   None
# ...                                                   ...   ...    ...
# 418650  {'status': 'BelowThreshold', 'ratings_count': ...  1993   None
# 418651  {'status': 'BelowThreshold', 'ratings_count': ...  1991   None
# 418652  {'status': 'BelowThreshold', 'ratings_count': ...  1978   None
# 418653  {'status': 'BelowThreshold', 'ratings_count': ...  1976   None
# 418654  {'status': 'Normal', 'ratings_count': 1642, 'r...     0   None
#
#         has_valid_ratings                                         source_url  \
# 0                   False  https://www.vivino.com/bacigalupi-zinfandel/w/...
# 1                   False  https://www.vivino.com/bacigalupi-zinfandel/w/...
# 2                   False  https://www.vivino.com/bacigalupi-zinfandel/w/...
# 3                   False  https://www.vivino.com/bacigalupi-zinfandel/w/...
# 4                   False  https://www.vivino.com/bacigalupi-zinfandel/w/...
# ...                   ...                                                ...
# 418650              False  https://www.vivino.com/crane-lake-pinot-noir/w...
# 418651              False  https://www.vivino.com/crane-lake-pinot-noir/w...
# 418652              False  https://www.vivino.com/crane-lake-pinot-noir/w...
# 418653              False  https://www.vivino.com/crane-lake-pinot-noir/w...
# 418654               True  https://www.vivino.com/crane-lake-pinot-noir/w...
#
#        Producer WineType Region Country Price
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...         ...      ...    ...     ...   ...
# 418650                      NaN
# 418651                      NaN
# 418652                      NaN
# 418653                      NaN
# 418654                      NaN
#
# [418655 rows x 13 columns]

# %%
final_all_vintages_df_True = final_all_vintages_df[final_all_vintages_df["has_valid_ratings"] == True]
# all_vintages_df_True["statistics"][2]
def extract_object_data(Object_data):
    """Extracts key-value pairs from an object and returns a Series."""
    if isinstance(Object_data, dict):
        return pd.Series(Object_data)
    else:
        return pd.Series()  # Handle other data types if needed

# Apply the function to the 'object_column' and create a new DataFrame
new_columns = final_all_vintages_df_True['statistics'].apply(extract_object_data)

# Concatenate the original DataFrame with the new columns
final_all_vintages_df_True = pd.concat([final_all_vintages_df_True, new_columns], axis=1)

# Print the modified DataFrame
final_all_vintages_df_True

selected_columns = ['id', 'name', 'year', 'ratings_average', 'reviews_count', 'has_valid_ratings']
df4 = final_all_vintages_df_True[selected_columns]

df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 20
#      17 final_all_vintages_df_True
#      19 selected_columns = ['id', 'name', 'year', 'ratings_average', 'reviews_count', 'has_valid_ratings']
# ---> 20 df4 = final_all_vintages_df_True[selected_columns]
#      22 df4
#
# File c:\Users\masca\Project_Wine\.conda\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\masca\Project_Wine\.conda\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\masca\Project_Wine\.conda\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['name', 'year'] not in index"

# %%
# Save the DataFrame to a CSV file
df4.to_csv('final_all_vintages_filtered.csv', index=False)

print("DataFrame saved to 'final_all_vintages_filtered.csv'")
# Out:
# DataFrame saved to 'final_all_vintages_filtered.csv'

# %%
df4
# Out:
#                id                                               name  year  \
# 6       147519855                          Bacigalupi Zinfandel 2016  2016
# 7       154248950                          Bacigalupi Zinfandel 2015  2015
# 22        4971178                               Bacigalupi Zinfandel     0
# 26      162909346  Domaine de La Romanée-Conti Romanée-Conti Gran...  2020
# 27      159459464  Domaine de La Romanée-Conti Romanée-Conti Gran...  2019
# ...           ...                                                ...   ...
# 418635    2175427                         Crane Lake Pinot Noir 2012  2012
# 418636    1377237                         Crane Lake Pinot Noir 2011  2011
# 418637    1236043                         Crane Lake Pinot Noir 2010  2010
# 418638    1171623                         Crane Lake Pinot Noir 2009  2009
# 418654    2425050                              Crane Lake Pinot Noir     0
#
#         ratings_average  reviews_count  has_valid_ratings
# 6                   4.5             20               True
# 7                   4.4             14               True
# 22                  4.4              3               True
# 26                  4.7             14               True
# 27                  4.9             18               True
# ...                 ...            ...                ...
# 418635              3.0             86               True
# 418636              2.9             27               True
# 418637              3.6              6               True
# 418638              3.3             13               True
# 418654              3.3             48               True
#
# [138207 rows x 6 columns]

# %%
# Out:
# DataFrame saved to 'final_all_vintages_filtered.csv'
