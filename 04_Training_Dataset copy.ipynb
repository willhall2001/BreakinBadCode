# %%
import os
import time
import requests
import pandas as pd
import geopandas as gpd
import folium
import openmeteo_requests
import requests_cache
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import re
from bs4 import BeautifulSoup

# %%
wines_file_path = r'C:\Users\fwhal\Downloads\CME528\Project\Repo-2\BreakinBadCode\Final_Wines_Of_Interest'
final_df_file_path = r'C:\Users\fwhal\Downloads\CME528\Project\Repo-2\BreakinBadCode\Final_DataFrames'


Dry_Wines = pd.read_csv(os.path.join(wines_file_path, 'Best_Drywines.csv'))
Medium_Wines = pd.read_csv(os.path.join(wines_file_path, 'Best_Medium_Drywines.csv'))
Sweet_Wines = pd.read_csv(os.path.join(wines_file_path, 'Best_Sweetwines.csv'))
Best_Wines = pd.read_csv(os.path.join(wines_file_path, 'Best_Wines.csv'))

FINAL_weather_data_FINAL = pd.read_csv(os.path.join(final_df_file_path, 'FINAL_weather_data_FINAL.csv'))

# %%
def Training_Data(weather_df, wine_df):
    """
    Input: Weather dataframe indexed on the daily scale,
        Vintage dataframe which has yearly bottles from the same producer and wine type
    Output: Weather dataframe indexed based on a single row for a producer and year 
        columns will be monthly min, max or average for the respective data per year
    """
    #Weather_df.index = pd.to_datetime(weather_df.index)
    producers = weather_df['Producer'].unique()

    #Initializes a dataframe 
    final_df = pd.DataFrame()

    #Check to see if date is the index
    if type(weather_df.index[0]) == int:

        weather_df = weather_df.set_index('Date') 

    #Filter the wine_df to make winetypes uniform 
    popular_wine_types = ['château margaux', 'cabernet sauvignon', 'pinot noir', 'zinfandel', 'syrah', 
                            'pinot gris', 'sauvignon blanc', 'chardonnay', 'baco noir', 'bordeaux',
                            'malbec', 'chardonnay', 'pinot grigio', 'merlot', 'sangiovese', 'shiraz',
                            'cabernet franc', 'muscat', 'grenache', 'sangiovese'  ]
    
    #Sets all the winetypes to be lower 
    wine_df['WineType'] = wine_df['WineType'].str.lower()

    #Filters through each of the winetypes, then changes the df winetype name if the wine type is in the row string 
    for winetype in popular_wine_types:

        wine_df['WineType']  = wine_df['WineType'].apply(lambda row: next((winetype for winetype in popular_wine_types if winetype in row), row))

    #Create a column for the year and produce all the unique years
    weather_df.index = pd.to_datetime(weather_df.index)
    weather_df['Year'] = weather_df.index.year
    unique_years = weather_df['Year'].unique()

    #Find all the unique months
    weather_df['Month'] = weather_df.index.month
    unique_months = weather_df['Month'].unique()

    #Gives key for the month names 
    month_names = {1 : 'January', 2 : 'February', 3 : 'March', 4 : 'April', 5 : 'May', 
                                  6 : 'June', 7 : 'July', 8 : 'August', 9 : 'September', 10 : 'October', 11 : 'November',
                                  12 : 'December'}

    for producer in producers:

        #Filter the data based on the producer
        producer_df = weather_df[weather_df['Producer'] == producer]

        #Iterate over each unique year
        for year in unique_years:
            
            #Filter the data for the specific year
            yearly_df = producer_df[producer_df['Year'] == year]

            #Creates initial data
            yearly_data = {'Producer' : producer, 'Year' : year}

            #Ierate over each unique month
            for month in unique_months: 

                #Filter the data for the specific month
                monthly_df = yearly_df[yearly_df['Month'] == month]

                #Group by month
                Grouped_Daily_into_Monthly = monthly_df.groupby(monthly_df.index.to_period('M'))

                #Change month number to month name
                month = month_names[month]

                yearly_data.update({
                    
                    'WineType' : Grouped_Daily_into_Monthly['Top WineType'].first()[0],
                    'District' : Grouped_Daily_into_Monthly['Top District'].first()[0],
                    f'{month} Max Temp (°C)' : Grouped_Daily_into_Monthly['Max Temp (°C)'].max().iloc[0],
                    f'{month} Min Temp (°C)' : Grouped_Daily_into_Monthly['Min Temp (°C)'].min().iloc[0],
                    f'{month} Avg Temp (°C)' : Grouped_Daily_into_Monthly['Avg Temp (°C)'].mean().iloc[0],
                    f'{month} Max Relative Humidity' : Grouped_Daily_into_Monthly['Max Relative Humidity'].max().iloc[0],
                    f'{month} Min Relative Humidity' : Grouped_Daily_into_Monthly['Min Relative Humidity'].min().iloc[0],
                    f'{month} Avg Relative Humidity' : Grouped_Daily_into_Monthly['Max Relative Humidity'].mean().iloc[0],
                    f'{month} Cumulative Rain (mm)' : Grouped_Daily_into_Monthly['Cumulative Rain (mm)'].sum().iloc[0],
                    f'{month} Cumulative Snow (mm)' : Grouped_Daily_into_Monthly['Cumulative Snow (mm)'].sum().iloc[0],
                    f'{month} Cumulative Precip (mm)' : Grouped_Daily_into_Monthly['Cumulative Rain (mm)'].sum().iloc[0] + Grouped_Daily_into_Monthly['Cumulative Snow (mm)'].sum().iloc[0],
                    f'{month} Cumulative Snow (mm)' : Grouped_Daily_into_Monthly['Cumulative Snow (mm)'].sum().iloc[0],
                    f'{month} Avg Cloud Cover (%)' : Grouped_Daily_into_Monthly['Avg Cloud Cover (%)'].mean().iloc[0],
                    f'{month} Max Wind Speed (Km/h)' : Grouped_Daily_into_Monthly['Max Wind Speed (Km/h)'].max().iloc[0],
                    f'{month} Min Wind Speed (Km/h)' : Grouped_Daily_into_Monthly['Min Wind Speed (Km/h)'].min().iloc[0],
                    f'{month} Avg Wind Speed (Km/h)' : Grouped_Daily_into_Monthly['Avg Wind Speed (Km/h)'].mean().iloc[0],
                    f'{month} Avg Daylight Hours' : Grouped_Daily_into_Monthly['Daylight Hours'].mean().iloc[0], 
                    f'{month} Days Below 0 (°C)': (monthly_df['Avg Temp (°C)'] <= 0).sum(),
                    f'{month} Days Above 32 (°C)': (monthly_df['Avg Temp (°C)'] > 32).sum()

                })
            
            #Adds this yearly data to original df
            final_df = pd.concat([final_df, pd.DataFrame([yearly_data])], ignore_index=True)
    
    #Add a producer/year column for future merging and reset index
    final_df = final_df.reset_index()
    final_df['Producer_WineType_Year'] = final_df['Producer'] + '/' + final_df['WineType'] + '/' + str(final_df['Year'])
    final_df['Producer_WineType_Year'] = final_df['Producer_WineType_Year'].str.lower()

    weather_df_columns = final_df.drop(columns = ['index'])
    print(final_df)

    #Format wine_df 
    wine_df['Producer_WineType_Year'] = wine_df['Producer'] + '/' + wine_df['WineType'] + '/' + str(wine_df['year'])
    wine_df['Producer_WineType_Year'] = wine_df['Producer_WineType_Year'].str.lower()

    #Combine the two dataframes     
    final_df = pd.merge(final_df, wine_df, on = 'Producer_WineType_Year', how = 'left')
    
    #Modify the dataframe for easier viewing
    final_df = final_df.drop(columns = ['index', 'year', 'Producer_y', 'WineType_y', 'has_valid_ratings', 'Producer_WineType_Year'])
    
    final_df.insert(0, 'Producer', final_df.pop('Producer_x'))
    final_df.insert(1, 'WineType', final_df.pop('WineType_x'))
    final_df.insert(2, 'District', final_df.pop('District'))
    final_df.insert(3, 'Region', final_df.pop('Region'))
    final_df.insert(4, 'Country', final_df.pop('Country'))
    final_df.insert(5, 'Year', final_df.pop('Year'))
    final_df.insert(5, 'Ratings_Average', final_df.pop('ratings_average'))

    #Drop all the rows that have NAN in the ratings average column 
    final_df = final_df.dropna(subset = ['Ratings_Average'])

    return final_df

# %%
Dry_Wines
# Out:
#            id                                             name_x  \
# 0   156238156  Beringer Beringer Bros. Bourbon Barrel Aged Ca...
# 1   167029502                     Bread & Butter Pinot Noir 2021
# 2    85993665             Casa Ferreirinha Papa Figos Douro 2016
# 3    99119393                      Rutini Cabernet - Malbec 2016
# 4   156135225               Marqués de Riscal Rioja Reserva 2018
# 5   150266396            Bodegas Marqués de Cáceres Crianza 2017
# 6   162874246    Austin Hope Austin Hope Cabernet Sauvignon 2020
# 7   160471734              Barbanera Gigino 80 Anniversario 2018
# 8    92859032                      Faust Cabernet Sauvignon 2016
# 9     4051132               Bodegas Faustino I Gran Reserva 2004
# 10   14344063                           Montes Purple Angel 2015
# 11    4285474           Hall Napa Valley Cabernet Sauvignon 2014
# 12    1364689                Don Melchor Cabernet Sauvignon 2010
# 13  156516648  Catena Zapata Nicasia Vineyards Red Blend Malb...
# 14    4091987                Don Melchor Cabernet Sauvignon 2014
# 15    2061644                Aalto PS (Pagos Seleccionados) 2011
# 16    1186195  Château Lagrange Saint-Julien (Grand Cru Class...
# 17    1468284                           Montes Purple Angel 2011
# 18    1740597                  Muga Prado Enea Gran Reserva 2010
# 19   94288357  Château Smith Haut-Lafitte Pessac-Léognan (Gra...
# 20  159375544                              Tenuta Luce Luce 2019
#
#           Country            Region                    Producer  \
# 0   United States       Napa Valley                    Beringer
# 1   United States       Napa Valley              Bread & Butter
# 2        Portugal             Douro            Casa Ferreirinha
# 3       Argentina           Mendoza                      Rutini
# 4           Spain             Rioja           Marqués de Riscal
# 5           Spain             Rioja  Bodegas Marqués de Cáceres
# 6   United States       Paso Robles                 Austin Hope
# 7           Italy           Toscana                   Barbanera
# 8   United States       Napa Valley                       Faust
# 9           Spain             Rioja            Bodegas Faustino
# 10          Chile  Colchagua Valley                      Montes
# 11  United States       Napa Valley                        Hall
# 12          Chile       Puente Alto                 Don Melchor
# 13      Argentina      Vista Flores               Catena Zapata
# 14          Chile       Puente Alto                 Don Melchor
# 15          Spain  Ribera del Duero                       Aalto
# 16         France      Saint-Julien            Château Lagrange
# 17          Chile  Colchagua Valley                      Montes
# 18          Spain             Rioja                        Muga
# 19         France    Pessac-Léognan  Château Smith Haut-Lafitte
# 20          Italy           Toscana                 Tenuta Luce
#
#                                              WineType    year  \
# 0   Beringer Bros. Bourbon Barrel Aged Cabernet Sa...  2016.0
# 1                                          Pinot Noir  2021.0
# 2                                    Papa Figos Douro  2016.0
# 3                                   Cabernet - Malbec  2016.0
# 4                                       Rioja Reserva  2018.0
# 5                                             Crianza  2017.0
# 6                      Austin Hope Cabernet Sauvignon  2020.0
# 7                              Gigino 80 Anniversario  2018.0
# 8                                  Cabernet Sauvignon  2016.0
# 9                                      I Gran Reserva  2004.0
# 10                                       Purple Angel  2015.0
# 11                     Napa Valley Cabernet Sauvignon  2014.0
# 12                                 Cabernet Sauvignon  2010.0
# 13                 Nicasia Vineyards Red Blend Malbec  2018.0
# 14                                 Cabernet Sauvignon  2014.0
# 15                           PS (Pagos Seleccionados)  2011.0
# 16                    Saint-Julien (Grand Cru Classé)  2005.0
# 17                                       Purple Angel  2011.0
# 18                            Prado Enea Gran Reserva  2010.0
# 19                  Pessac-Léognan (Grand Cru Classé)  2016.0
# 20                                               Luce  2019.0
#
#     has_valid_ratings  ratings_average  reviews_count  ...              type  \
# 0                True              4.1         4089.0  ...         price_qpr
# 1                True              4.0         3171.0  ...   best_user_rated
# 2                True              3.9         2767.0  ...  oldest_available
# 3                True              4.2         3286.0  ...   most_user_rated
# 4                True              4.1         3220.0  ...        top_listed
# 5                True              3.7         3146.0  ...   best_user_rated
# 6                True              4.5         3107.0  ...  price_discounted
# 7                True              4.3         1460.0  ...         price_qpr
# 8                True              4.3         1429.0  ...   most_user_rated
# 9                True              4.0         2356.0  ...   best_user_rated
# 10               True              4.5         1108.0  ...         price_qpr
# 11               True              4.3         1053.0  ...   most_user_rated
# 12               True              4.6         1768.0  ...        top_listed
# 13               True              4.0         1331.0  ...   most_user_rated
# 14               True              4.6         1024.0  ...  latest_available
# 15               True              4.6          811.0  ...         price_qpr
# 16               True              4.2          743.0  ...   critic_favorite
# 17               True              4.3          764.0  ...  oldest_available
# 18               True              4.3         1022.0  ...  latest_available
# 19               True              4.4          423.0  ...   best_user_rated
# 20               True              4.4          346.0  ...   best_user_rated
#
#    Tannin  Acidity  Intensity  Sweetness  Acidity_norm  Tannin_norm  \
# 0     4.0      3.5        5.0        1.0          0.25        0.750
# 1     2.0      3.5        3.0        1.0          0.25        0.250
# 2     4.0      3.0        5.0        1.0          0.00        0.750
# 3     3.5      3.0        4.5        1.0          0.00        0.625
# 4     4.5      4.0        4.0        1.0          0.50        0.875
# 5     4.5      4.0        4.0        1.0          0.50        0.875
# 6     4.5      3.5        5.0        1.0          0.25        0.875
# 7     3.0      3.0        3.0        1.0          0.00        0.500
# 8     4.0      3.5        5.0        1.0          0.25        0.750
# 9     4.5      4.0        4.0        1.0          0.50        0.875
# 10    4.0      3.0        5.0        1.0          0.00        0.750
# 11    4.0      3.5        5.0        1.0          0.25        0.750
# 12    3.5      3.0        4.5        1.0          0.00        0.625
# 13    3.0      3.5        4.0        1.5          0.25        0.500
# 14    3.5      3.0        4.5        1.0          0.00        0.625
# 15    4.0      4.0        4.0        1.0          0.50        0.750
# 16    4.5      4.5        4.0        1.0          0.75        0.875
# 17    4.0      3.0        5.0        1.0          0.00        0.750
# 18    4.5      4.0        4.0        1.0          0.50        0.875
# 19    5.0      4.5        4.5        1.0          0.75        1.000
# 20    3.0      3.0        3.0        1.0          0.00        0.500
#
#     Intensity_norm      score  price_range
# 0             1.00  203.81300         0-30
# 1             0.00  156.72600         0-30
# 2             1.00  136.62850         0-30
# 3             0.75  161.55525        30-60
# 4             0.50  158.89875        30-60
# 5             0.50  155.45975        30-60
# 6             1.00  149.25725       60-100
# 7             0.00   67.08600       60-100
# 8             1.00   65.46100       60-100
# 9             0.50  107.76975      100-150
# 10            1.00   44.73850      100-150
# 11            1.00   43.93100      100-150
# 12            0.75   72.90225      150-200
# 13            0.50   51.96850      150-200
# 14            0.75   35.70225      150-200
# 15            0.50   20.93550      200-300
# 16            0.50   14.02225      200-300
# 17            1.00   13.49750      200-300
# 18            0.50   14.34875         300+
# 19            0.75  -10.58150         300+
# 20            0.00  -14.09400         300+
#
# [21 rows x 21 columns]

# %%
FINAL_weather_data_FINAL.head(1)
# Out:
#                         Date          Producer        Top WineType  \
# 0  2000-01-01 00:00:00+00:00  Fisher Vineyards  cabernet sauvignon
#
#    Max Temp (°C)  Min Temp (°C)  Avg Temp (°C)  Max Relative Humidity  \
# 0        11.8295         2.2295       5.831583              99.291336
#
#    Min Relative Humidity  Avg Relative Humidity  \
# 0              55.711567               87.09057
#
#    Cumulative Precip (Rain + Snow)(mm)  ...  Max Wind Speed (Km/h)  \
# 0                                  0.0  ...               18.25026
#
#    Min Wind Speed (Km/h)  Avg Wind Speed (Km/h)  Daylight Hours  \
# 0                   0.72               6.144656        9.528758
#
#      Top Country  Top Region  Top District  Price       Lat        Long
# 0  United States  California        Sonoma  240.0  38.51108 -122.847339
#
# [1 rows x 23 columns]

# %%
df = Training_Data(FINAL_weather_data_FINAL, Dry_Wines)
df
# Out:
# C:\Users\fwhal\AppData\Local\Temp\ipykernel_27984\103709816.py:68: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Grouped_Daily_into_Monthly = monthly_df.groupby(monthly_df.index.to_period('M'))
# C:\Users\fwhal\AppData\Local\Temp\ipykernel_27984\103709816.py:75: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'WineType' : Grouped_Daily_into_Monthly['Top WineType'].first()[0],
# C:\Users\fwhal\AppData\Local\Temp\ipykernel_27984\103709816.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'District' : Grouped_Daily_into_Monthly['Top District'].first()[0],
#      index          Producer  Year            WineType    District  \
# 0        0  Fisher Vineyards  2000  cabernet sauvignon      Sonoma
# 1        1  Fisher Vineyards  2001  cabernet sauvignon      Sonoma
# 2        2  Fisher Vineyards  2002  cabernet sauvignon      Sonoma
# 3        3  Fisher Vineyards  2003  cabernet sauvignon      Sonoma
# 4        4  Fisher Vineyards  2004  cabernet sauvignon      Sonoma
# ..     ...               ...   ...                 ...         ...
# 595    595     Catena Zapata  2019              malbec  San Rafael
# 596    596     Catena Zapata  2020              malbec  San Rafael
# 597    597     Catena Zapata  2021              malbec  San Rafael
# 598    598     Catena Zapata  2022              malbec  San Rafael
# 599    599     Catena Zapata  2023              malbec  San Rafael
#
#      January Max Temp (°C)  January Min Temp (°C)  January Avg Temp (°C)  \
# 0                15.929500                 1.0295               9.091798
# 1                19.029500                -1.5705               7.234540
# 2                17.429500                -1.5705               7.662296
# 3                19.929500                 1.8795              11.077349
# 4                16.579498                -0.8705               8.426812
# ..                     ...                    ...                    ...
# 595              31.341500                 1.6915              18.903328
# 596              29.841500                 7.7915              19.923018
# 597              30.141499                 5.7915              16.999766
# 598              28.441500                 3.4415              18.462804
# 599              28.541500                 6.4415              18.723758
#
#      January Max Relative Humidity  January Min Relative Humidity  ...  \
# 0                       100.000000                      33.359756  ...
# 1                       100.000000                      30.501522  ...
# 2                       100.000000                      30.890038  ...
# 3                       100.000000                      32.727215  ...
# 4                       100.000000                      35.712963  ...
# ..                             ...                            ...  ...
# 595                      96.748116                       7.920898  ...
# 596                     100.000000                      11.347249  ...
# 597                      97.157760                       9.584439  ...
# 598                      96.487990                      22.756386  ...
# 599                      94.606240                      22.057447  ...
#
#      December Cumulative Snow (mm)  December Cumulative Precip (mm)  \
# 0                             0.00                        17.900000
# 1                             0.00                       247.700000
# 2                             0.77                       391.270000
# 3                             0.00                       248.899999
# 4                             0.00                       233.400000
# ..                             ...                              ...
# 595                           0.00                        19.600000
# 596                           0.00                         9.800000
# 597                           0.00                        65.400001
# 598                           0.00                        30.000001
# 599                           0.00                         3.000000
#
#      December Avg Cloud Cover (%)  December Max Wind Speed (Km/h)  \
# 0                       63.418011                       14.494192
# 1                       78.353494                       27.026386
# 2                       72.919354                       36.258274
# 3                       75.965053                       27.959742
# 4                       56.950268                       25.942488
# ..                            ...                             ...
# 595                     24.799731                       26.282465
# 596                     13.366935                       39.345543
# 597                     45.400538                       24.975283
# 598                     28.844086                       29.957968
# 599                     25.232527                       38.479603
#
#      December Min Wind Speed (Km/h)  December Avg Wind Speed (Km/h)  \
# 0                          0.360000                        5.201014
# 1                          0.000000                        8.259984
# 2                          0.360000                        9.049175
# 3                          0.509117                        8.032801
# 4                          0.360000                        6.039130
# ..                              ...                             ...
# 595                        0.360000                        8.305897
# 596                        0.000000                        8.443003
# 597                        0.000000                        7.176740
# 598                        0.804984                        8.073395
# 599                        0.000000                        7.433448
#
#      December Avg Daylight Hours  December Days Below 0 (°C)  \
# 0                       9.530056                           0
# 1                       9.531516                           0
# 2                       9.532616                           0
# 3                       9.533591                           0
# 4                       9.529678                           0
# ..                           ...                         ...
# 595                    14.314198                           0
# 596                    14.317290                           0
# 597                    14.316434                           0
# 598                    14.315680                           0
# 599                    14.314503                           0
#
#      December Days Above 32 (°C)  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ..                           ...
# 595                            0
# 596                            0
# 597                            0
# 598                            0
# 599                            0
#
#                                 Producer_WineType_Year
# 0    fisher vineyards/cabernet sauvignon/0      200...
# 1    fisher vineyards/cabernet sauvignon/0      200...
# 2    fisher vineyards/cabernet sauvignon/0      200...
# 3    fisher vineyards/cabernet sauvignon/0      200...
# 4    fisher vineyards/cabernet sauvignon/0      200...
# ..                                                 ...
# 595  catena zapata/malbec/0      2000\n1      2001\...
# 596  catena zapata/malbec/0      2000\n1      2001\...
# 597  catena zapata/malbec/0      2000\n1      2001\...
# 598  catena zapata/malbec/0      2000\n1      2001\...
# 599  catena zapata/malbec/0      2000\n1      2001\...
#
# [600 rows x 198 columns]
# Empty DataFrame
# Columns: [Producer, WineType, District, Region, Country, Ratings_Average, Year, January Max Temp (°C), January Min Temp (°C), January Avg Temp (°C), January Max Relative Humidity, January Min Relative Humidity, January Avg Relative Humidity, January Cumulative Rain (mm), January Cumulative Snow (mm), January Cumulative Precip (mm), January Avg Cloud Cover (%), January Max Wind Speed (Km/h), January Min Wind Speed (Km/h), January Avg Wind Speed (Km/h), January Avg Daylight Hours, January Days Below 0 (°C), January Days Above 32 (°C), February Max Temp (°C), February Min Temp (°C), February Avg Temp (°C), February Max Relative Humidity, February Min Relative Humidity, February Avg Relative Humidity, February Cumulative Rain (mm), February Cumulative Snow (mm), February Cumulative Precip (mm), February Avg Cloud Cover (%), February Max Wind Speed (Km/h), February Min Wind Speed (Km/h), February Avg Wind Speed (Km/h), February Avg Daylight Hours, February Days Below 0 (°C), February Days Above 32 (°C), March Max Temp (°C), March Min Temp (°C), March Avg Temp (°C), March Max Relative Humidity, March Min Relative Humidity, March Avg Relative Humidity, March Cumulative Rain (mm), March Cumulative Snow (mm), March Cumulative Precip (mm), March Avg Cloud Cover (%), March Max Wind Speed (Km/h), March Min Wind Speed (Km/h), March Avg Wind Speed (Km/h), March Avg Daylight Hours, March Days Below 0 (°C), March Days Above 32 (°C), April Max Temp (°C), April Min Temp (°C), April Avg Temp (°C), April Max Relative Humidity, April Min Relative Humidity, April Avg Relative Humidity, April Cumulative Rain (mm), April Cumulative Snow (mm), April Cumulative Precip (mm), April Avg Cloud Cover (%), April Max Wind Speed (Km/h), April Min Wind Speed (Km/h), April Avg Wind Speed (Km/h), April Avg Daylight Hours, April Days Below 0 (°C), April Days Above 32 (°C), May Max Temp (°C), May Min Temp (°C), May Avg Temp (°C), May Max Relative Humidity, May Min Relative Humidity, May Avg Relative Humidity, May Cumulative Rain (mm), May Cumulative Snow (mm), May Cumulative Precip (mm), May Avg Cloud Cover (%), May Max Wind Speed (Km/h), May Min Wind Speed (Km/h), May Avg Wind Speed (Km/h), May Avg Daylight Hours, May Days Below 0 (°C), May Days Above 32 (°C), June Max Temp (°C), June Min Temp (°C), June Avg Temp (°C), June Max Relative Humidity, June Min Relative Humidity, June Avg Relative Humidity, June Cumulative Rain (mm), June Cumulative Snow (mm), June Cumulative Precip (mm), June Avg Cloud Cover (%), June Max Wind Speed (Km/h), June Min Wind Speed (Km/h), June Avg Wind Speed (Km/h), ...]
# Index: []
#
# [0 rows x 213 columns]

# %%
for i in df.columns:
    print(i)
# Out:
# Producer
# WineType
# District
# Region
# Country
# Ratings_Average
# Year
# January Max Temp (°C)
# January Min Temp (°C)
# January Avg Temp (°C)
# January Max Relative Humidity
# January Min Relative Humidity
# January Avg Relative Humidity
# January Cumulative Rain (mm)
# January Cumulative Snow (mm)
# January Cumulative Precip (mm)
# January Avg Cloud Cover (%)
# January Max Wind Speed (Km/h)
# January Min Wind Speed (Km/h)
# January Avg Wind Speed (Km/h)
# January Avg Daylight Hours
# January Days Below 0 (°C)
# January Days Above 32 (°C)
# February Max Temp (°C)
# February Min Temp (°C)
# February Avg Temp (°C)
# February Max Relative Humidity
# February Min Relative Humidity
# February Avg Relative Humidity
# February Cumulative Rain (mm)
# February Cumulative Snow (mm)
# February Cumulative Precip (mm)
# February Avg Cloud Cover (%)
# February Max Wind Speed (Km/h)
# February Min Wind Speed (Km/h)
# February Avg Wind Speed (Km/h)
# February Avg Daylight Hours
# February Days Below 0 (°C)
# February Days Above 32 (°C)
# March Max Temp (°C)
# March Min Temp (°C)
# March Avg Temp (°C)
# March Max Relative Humidity
# March Min Relative Humidity
# March Avg Relative Humidity
# March Cumulative Rain (mm)
# March Cumulative Snow (mm)
# March Cumulative Precip (mm)
# March Avg Cloud Cover (%)
# March Max Wind Speed (Km/h)
# March Min Wind Speed (Km/h)
# March Avg Wind Speed (Km/h)
# March Avg Daylight Hours
# March Days Below 0 (°C)
# March Days Above 32 (°C)
# April Max Temp (°C)
# April Min Temp (°C)
# April Avg Temp (°C)
# April Max Relative Humidity
# April Min Relative Humidity
# April Avg Relative Humidity
# April Cumulative Rain (mm)
# April Cumulative Snow (mm)
# April Cumulative Precip (mm)
# April Avg Cloud Cover (%)
# April Max Wind Speed (Km/h)
# April Min Wind Speed (Km/h)
# April Avg Wind Speed (Km/h)
# April Avg Daylight Hours
# April Days Below 0 (°C)
# April Days Above 32 (°C)
# May Max Temp (°C)
# May Min Temp (°C)
# May Avg Temp (°C)
# May Max Relative Humidity
# May Min Relative Humidity
# May Avg Relative Humidity
# May Cumulative Rain (mm)
# May Cumulative Snow (mm)
# May Cumulative Precip (mm)
# May Avg Cloud Cover (%)
# May Max Wind Speed (Km/h)
# May Min Wind Speed (Km/h)
# May Avg Wind Speed (Km/h)
# May Avg Daylight Hours
# May Days Below 0 (°C)
# May Days Above 32 (°C)
# June Max Temp (°C)
# June Min Temp (°C)
# June Avg Temp (°C)
# June Max Relative Humidity
# June Min Relative Humidity
# June Avg Relative Humidity
# June Cumulative Rain (mm)
# June Cumulative Snow (mm)
# June Cumulative Precip (mm)
# June Avg Cloud Cover (%)
# June Max Wind Speed (Km/h)
# June Min Wind Speed (Km/h)
# June Avg Wind Speed (Km/h)
# June Avg Daylight Hours
# June Days Below 0 (°C)
# June Days Above 32 (°C)
# July Max Temp (°C)
# July Min Temp (°C)
# July Avg Temp (°C)
# July Max Relative Humidity
# July Min Relative Humidity
# July Avg Relative Humidity
# July Cumulative Rain (mm)
# July Cumulative Snow (mm)
# July Cumulative Precip (mm)
# July Avg Cloud Cover (%)
# July Max Wind Speed (Km/h)
# July Min Wind Speed (Km/h)
# July Avg Wind Speed (Km/h)
# July Avg Daylight Hours
# July Days Below 0 (°C)
# July Days Above 32 (°C)
# August Max Temp (°C)
# August Min Temp (°C)
# August Avg Temp (°C)
# August Max Relative Humidity
# August Min Relative Humidity
# August Avg Relative Humidity
# August Cumulative Rain (mm)
# August Cumulative Snow (mm)
# August Cumulative Precip (mm)
# August Avg Cloud Cover (%)
# August Max Wind Speed (Km/h)
# August Min Wind Speed (Km/h)
# August Avg Wind Speed (Km/h)
# August Avg Daylight Hours
# August Days Below 0 (°C)
# August Days Above 32 (°C)
# September Max Temp (°C)
# September Min Temp (°C)
# September Avg Temp (°C)
# September Max Relative Humidity
# September Min Relative Humidity
# September Avg Relative Humidity
# September Cumulative Rain (mm)
# September Cumulative Snow (mm)
# September Cumulative Precip (mm)
# September Avg Cloud Cover (%)
# September Max Wind Speed (Km/h)
# September Min Wind Speed (Km/h)
# September Avg Wind Speed (Km/h)
# September Avg Daylight Hours
# September Days Below 0 (°C)
# September Days Above 32 (°C)
# October Max Temp (°C)
# October Min Temp (°C)
# October Avg Temp (°C)
# October Max Relative Humidity
# October Min Relative Humidity
# October Avg Relative Humidity
# October Cumulative Rain (mm)
# October Cumulative Snow (mm)
# October Cumulative Precip (mm)
# October Avg Cloud Cover (%)
# October Max Wind Speed (Km/h)
# October Min Wind Speed (Km/h)
# October Avg Wind Speed (Km/h)
# October Avg Daylight Hours
# October Days Below 0 (°C)
# October Days Above 32 (°C)
# November Max Temp (°C)
# November Min Temp (°C)
# November Avg Temp (°C)
# November Max Relative Humidity
# November Min Relative Humidity
# November Avg Relative Humidity
# November Cumulative Rain (mm)
# November Cumulative Snow (mm)
# November Cumulative Precip (mm)
# November Avg Cloud Cover (%)
# November Max Wind Speed (Km/h)
# November Min Wind Speed (Km/h)
# November Avg Wind Speed (Km/h)
# November Avg Daylight Hours
# November Days Below 0 (°C)
# November Days Above 32 (°C)
# December Max Temp (°C)
# December Min Temp (°C)
# December Avg Temp (°C)
# December Max Relative Humidity
# December Min Relative Humidity
# December Avg Relative Humidity
# December Cumulative Rain (mm)
# December Cumulative Snow (mm)
# December Cumulative Precip (mm)
# December Avg Cloud Cover (%)
# December Max Wind Speed (Km/h)
# December Min Wind Speed (Km/h)
# December Avg Wind Speed (Km/h)
# December Avg Daylight Hours
# December Days Below 0 (°C)
# December Days Above 32 (°C)
# id
# name_x
# reviews_count
# amount
# type
# Tannin
# Acidity
# Intensity
# Sweetness
# Acidity_norm
# Tannin_norm
# Intensity_norm
# score
# price_range
